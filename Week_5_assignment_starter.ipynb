# %% [markdown]
# # DS Automation Assignment

# %% [markdown]
# Using our prepared churn data from week 2:
# - use pycaret to find an ML algorithm that performs best on the data
#     - Choose a metric you think is best to use for finding the best model; by default, it is accuracy but it could be AUC, precision, recall, etc. The week 3 FTE has some information on these different metrics.
# - save the model to disk
# - create a Python script/file/module with a function that takes a pandas dataframe as an input and returns the probability of churn for each row in the dataframe
#     - your Python file/function should print out the predictions for new data (new_churn_data.csv)
#     - the true values for the new data are [1, 0, 0, 1, 0] if you're interested
# - test your Python module and function with the new data, new_churn_data.csv
# - write a short summary of the process and results at the end of this notebook
# - upload this Jupyter Notebook and Python file to a Github repository, and turn in a link to the repository in the week 5 assignment dropbox
#
# *Optional* challenges:
# - return the probability of churn for each new prediction, and the percentile where that prediction is in the distribution of probability predictions from the training dataset (e.g. a high probability of churn like 0.78 might be at the 90th percentile)
# - use other autoML packages, such as TPOT, H2O, MLBox, etc, and compare performance and features with pycaret
# - create a class in your Python module to hold the functions that you created
# - accept user input to specify a file using a tool such as Python's `input()` function, the `click` package for command-line arguments, or a GUI
# - Use the unmodified churn data (new_unmodified_churn_data.csv) in your Python script. This will require adding the same preprocessing steps from week 2 since this data is like the original unmodified dataset from week 1.

# %%
# !conda create -n msds python=3.10.14 -y
# !conda activate msds
# !pip install --upgrade pycaret
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DELL\Downloads\New folder\envs\msds
#
#   added / updated specs:
#     - python=3.10.14
#
#
# The following NEW packages will be INSTALLED:
#
#   bzip2              pkgs/main/win-64::bzip2-1.0.8-h2bbff1b_6
#   ca-certificates    pkgs/main/win-64::ca-certificates-2024.7.2-haa95532_0
#   libffi             pkgs/main/win-64::libffi-3.4.4-hd77b12b_1
#   openssl            pkgs/main/win-64::openssl-3.0.15-h827c3e9_0
#   pip                pkgs/main/win-64::pip-24.2-py310haa95532_0
#   python             pkgs/main/win-64::python-3.10.14-he1021f5_1
#   setuptools         pkgs/main/win-64::setuptools-75.1.0-py310haa95532_0
#   sqlite             pkgs/main/win-64::sqlite-3.45.3-h2bbff1b_0
#   tk                 pkgs/main/win-64::tk-8.6.14-h0416ee5_0
#   tzdata             pkgs/main/noarch::tzdata-2024a-h04d1e81_0
#   vc                 pkgs/main/win-64::vc-14.40-h2eaa2aa_1
#   vs2015_runtime     pkgs/main/win-64::vs2015_runtime-14.40.33807-h98bb1dd_1
#   wheel              pkgs/main/win-64::wheel-0.44.0-py310haa95532_0
#   xz                 pkgs/main/win-64::xz-5.4.6-h8cc25b3_1
#   zlib               pkgs/main/win-64::zlib-1.2.13-h8cc25b3_1
#
#
#
# Downloading and Extracting Packages
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# #
# # To activate this environment, use
# #
# #     $ conda activate msds
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# WARNING: A space was detected in your requested environment path:
# 'C:\Users\DELL\Downloads\New folder\envs\msds'
# Spaces in paths can sometimes be problematic. To minimize issues,
# make sure you activate your environment before running any executables!
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.1.0
#   latest version: 24.7.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=24.7.1
# Requirement already satisfied: pycaret in c:\users\dell\downloads\new folder\lib\site-packages (3.3.2)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (8.10.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (7.6.5)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (4.64.1)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.23.5)
# Requirement already satisfied: pandas<2.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: jinja2>=3 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: scipy<=1.11.4,>=1.6.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.9.3)
# Requirement already satisfied: joblib<1.4,>=1.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: scikit-learn>1.4.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.4.2)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.0.2)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.12.3)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (4.5.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.56.4)
# Requirement already satisfied: requests>=2.27.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.28.1)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (8.5.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: cloudpickle in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: xxhash in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (3.5.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (3.6.3)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.10.0)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.13.5)
# Requirement already satisfied: sktime==0.26.0 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\dell\downloads\new folder\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: packaging in c:\users\dell\downloads\new folder\lib\site-packages (from sktime==0.26.0->pycaret) (22.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\dell\downloads\new folder\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from imbalanced-learn>=0.12.0->pycaret) (3.5.0)
# Requirement already satisfied: zipp>=3.20 in c:\users\dell\downloads\new folder\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.20.2)
# Requirement already satisfied: backcall in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.30 in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (2.11.2)
# Requirement already satisfied: stack-data in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\dell\downloads\new folder\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\dell\downloads\new folder\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\users\dell\downloads\new folder\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.5.2)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (9.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\downloads\new folder\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\dell\downloads\new folder\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\dell\downloads\new folder\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\dell\downloads\new folder\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\dell\downloads\new folder\lib\site-packages (from numba>=0.55.0->pycaret) (0.39.1)
# Requirement already satisfied: setuptools in c:\users\dell\downloads\new folder\lib\site-packages (from numba>=0.55.0->pycaret) (65.6.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\downloads\new folder\lib\site-packages (from pandas<2.2.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from plotly>=5.14.0->pycaret) (8.0.1)
# Requirement already satisfied: dash>=2.9.0 in c:\users\dell\downloads\new folder\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.18.1)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.10.7)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\dell\downloads\new folder\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.3)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\dell\downloads\new folder\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.0.11)
# Requirement already satisfied: urllib3 in c:\users\dell\downloads\new folder\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\dell\downloads\new folder\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\downloads\new folder\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\downloads\new folder\lib\site-packages (from requests>=2.27.1->pycaret) (2022.12.7)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.2)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.12.2)
# Requirement already satisfied: retrying in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\dell\downloads\new folder\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: comm>=0.1.1 in c:\users\dell\downloads\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\dell\downloads\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (7.3.4)
# Requirement already satisfied: pyzmq>=17 in c:\users\dell\downloads\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (23.2.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\dell\downloads\new folder\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\dell\downloads\new folder\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\dell\downloads\new folder\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: six in c:\users\dell\downloads\new folder\lib\site-packages (from patsy>=0.5.1->category-encoders>=2.4.0->pycaret) (1.16.0)
# Requirement already satisfied: wcwidth in c:\users\dell\downloads\new folder\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\dell\downloads\new folder\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.5.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\dell\downloads\new folder\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: pywin32>=1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: executing in c:\users\dell\downloads\new folder\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\dell\downloads\new folder\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\dell\downloads\new folder\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\dell\downloads\new folder\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.0.4)
# Requirement already satisfied: entrypoints in c:\users\dell\downloads\new folder\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: argon2-cffi in c:\users\dell\downloads\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\dell\downloads\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\dell\downloads\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\dell\downloads\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\dell\downloads\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\dell\downloads\new folder\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.2)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\dell\downloads\new folder\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.23.4)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: lxml in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.9.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.11.1)
# Requirement already satisfied: bleach in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\dell\downloads\new folder\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\dell\downloads\new folder\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\dell\downloads\new folder\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (3.5.0)
# Requirement already satisfied: websocket-client in c:\users\dell\downloads\new folder\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\dell\downloads\new folder\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\dell\downloads\new folder\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\dell\downloads\new folder\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\dell\downloads\new folder\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\dell\downloads\new folder\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.6.5->pycaret) (2.21)

# %%
import pandas as pd
df=pd.read_csv('C:/Users/DELL/Downloads/week2prepared_churn.csv',index_col='customerID')
df
df.drop('TotalCharges_to_MonthlyCharges',axis=1,inplace=True)

# %%
df
# Out:
#             tenure PhoneService        Contract              PaymentMethod  \
# customerID
# 7590-VHVEG       1           No  Month-to-month           Electronic check
# 5575-GNVDE      34          Yes        One year               Mailed check
# 3668-QPYBK       2          Yes  Month-to-month               Mailed check
# 7795-CFOCW      45           No        One year  Bank transfer (automatic)
# 9237-HQITU       2          Yes  Month-to-month           Electronic check
# ...            ...          ...             ...                        ...
# 6840-RESVB      24          Yes        One year               Mailed check
# 2234-XADUH      72          Yes        One year    Credit card (automatic)
# 4801-JZAZL      11           No  Month-to-month           Electronic check
# 8361-LTMKD       4          Yes  Month-to-month               Mailed check
# 3186-AJIEK      66          Yes        Two year  Bank transfer (automatic)
#
#             MonthlyCharges  TotalCharges Churn
# customerID
# 7590-VHVEG           29.85         29.85    No
# 5575-GNVDE           56.95       1889.50    No
# 3668-QPYBK           53.85        108.15   Yes
# 7795-CFOCW           42.30       1840.75    No
# 9237-HQITU           70.70        151.65   Yes
# ...                    ...           ...   ...
# 6840-RESVB           84.80       1990.50    No
# 2234-XADUH          103.20       7362.90    No
# 4801-JZAZL           29.60        346.45    No
# 8361-LTMKD           74.40        306.60   Yes
# 3186-AJIEK          105.65       6844.50    No
#
# [7043 rows x 7 columns]

# %%
from pycaret.classification import setup, compare_models, predict_model, save_model, load_model

# %% [markdown]
# PyCaret's classification module simplifies the machine learning workflow with user-friendly functions. The setup function initializes the environment and prepares the data. The compare_models function evaluates different algorithms to find the best one, while predict_model is used for making predictions. Additionally, save_model and load_model help manage trained models efficiently.

# %% [markdown]
#  We used the setup() method with the dataset (df) and specified the target variable as 'Churn' in order to prepare the data for automatic machine learning (AutoML). PyCaret's AutoML module was utilized for this purpose.

# %%
automl = setup(df, target='Churn')
# Out:
# <style type="text/css">
# #T_ce726_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ce726">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce726_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ce726_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce726_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ce726_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ce726_row0_col1" class="data row0 col1" >4181</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ce726_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ce726_row1_col1" class="data row1 col1" >Churn</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ce726_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_ce726_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ce726_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_ce726_row3_col1" class="data row3 col1" >No: 0, Yes: 1</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ce726_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_ce726_row4_col1" class="data row4 col1" >(7043, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ce726_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_ce726_row5_col1" class="data row5 col1" >(7043, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ce726_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_ce726_row6_col1" class="data row6 col1" >(4930, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ce726_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_ce726_row7_col1" class="data row7 col1" >(2113, 12)</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ce726_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_ce726_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ce726_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_ce726_row9_col1" class="data row9 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ce726_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_ce726_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ce726_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_ce726_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ce726_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_ce726_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ce726_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_ce726_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ce726_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_ce726_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ce726_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_ce726_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ce726_row16_col0" class="data row16 col0" >Fold Generator</td>
#       <td id="T_ce726_row16_col1" class="data row16 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ce726_row17_col0" class="data row17 col0" >Fold Number</td>
#       <td id="T_ce726_row17_col1" class="data row17 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ce726_row18_col0" class="data row18 col0" >CPU Jobs</td>
#       <td id="T_ce726_row18_col1" class="data row18 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ce726_row19_col0" class="data row19 col0" >Use GPU</td>
#       <td id="T_ce726_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ce726_row20_col0" class="data row20 col0" >Log Experiment</td>
#       <td id="T_ce726_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ce726_row21_col0" class="data row21 col0" >Experiment Name</td>
#       <td id="T_ce726_row21_col1" class="data row21 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ce726_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ce726_row22_col0" class="data row22 col0" >USI</td>
#       <td id="T_ce726_row22_col1" class="data row22 col1" >a70d</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here the used the compare models method() to compare the different models with each model performances

# %%
best_model = compare_models(sort='AUC')
# Out:
# <style type="text/css">
# #T_cf15b th {
#   text-align: left;
# }
# #T_cf15b_row0_col0, #T_cf15b_row0_col4, #T_cf15b_row0_col5, #T_cf15b_row0_col6, #T_cf15b_row0_col7, #T_cf15b_row1_col0, #T_cf15b_row1_col1, #T_cf15b_row1_col2, #T_cf15b_row1_col3, #T_cf15b_row1_col4, #T_cf15b_row1_col5, #T_cf15b_row1_col6, #T_cf15b_row1_col7, #T_cf15b_row2_col0, #T_cf15b_row2_col1, #T_cf15b_row2_col2, #T_cf15b_row2_col3, #T_cf15b_row2_col4, #T_cf15b_row2_col6, #T_cf15b_row2_col7, #T_cf15b_row3_col0, #T_cf15b_row3_col1, #T_cf15b_row3_col2, #T_cf15b_row3_col3, #T_cf15b_row3_col4, #T_cf15b_row3_col5, #T_cf15b_row3_col6, #T_cf15b_row3_col7, #T_cf15b_row4_col0, #T_cf15b_row4_col1, #T_cf15b_row4_col2, #T_cf15b_row4_col3, #T_cf15b_row4_col4, #T_cf15b_row4_col5, #T_cf15b_row5_col0, #T_cf15b_row5_col1, #T_cf15b_row5_col2, #T_cf15b_row5_col3, #T_cf15b_row5_col4, #T_cf15b_row5_col5, #T_cf15b_row5_col6, #T_cf15b_row5_col7, #T_cf15b_row6_col0, #T_cf15b_row6_col1, #T_cf15b_row6_col2, #T_cf15b_row6_col3, #T_cf15b_row6_col5, #T_cf15b_row6_col6, #T_cf15b_row6_col7, #T_cf15b_row7_col0, #T_cf15b_row7_col1, #T_cf15b_row7_col2, #T_cf15b_row7_col3, #T_cf15b_row7_col4, #T_cf15b_row7_col5, #T_cf15b_row7_col6, #T_cf15b_row7_col7, #T_cf15b_row8_col0, #T_cf15b_row8_col1, #T_cf15b_row8_col2, #T_cf15b_row8_col3, #T_cf15b_row8_col4, #T_cf15b_row8_col5, #T_cf15b_row8_col6, #T_cf15b_row8_col7, #T_cf15b_row9_col0, #T_cf15b_row9_col1, #T_cf15b_row9_col2, #T_cf15b_row9_col3, #T_cf15b_row9_col4, #T_cf15b_row9_col5, #T_cf15b_row9_col6, #T_cf15b_row9_col7, #T_cf15b_row10_col0, #T_cf15b_row10_col1, #T_cf15b_row10_col2, #T_cf15b_row10_col3, #T_cf15b_row10_col4, #T_cf15b_row10_col5, #T_cf15b_row10_col6, #T_cf15b_row10_col7, #T_cf15b_row11_col0, #T_cf15b_row11_col1, #T_cf15b_row11_col2, #T_cf15b_row11_col3, #T_cf15b_row11_col4, #T_cf15b_row11_col5, #T_cf15b_row11_col6, #T_cf15b_row11_col7, #T_cf15b_row12_col0, #T_cf15b_row12_col1, #T_cf15b_row12_col2, #T_cf15b_row12_col3, #T_cf15b_row12_col4, #T_cf15b_row12_col5, #T_cf15b_row12_col6, #T_cf15b_row12_col7, #T_cf15b_row13_col0, #T_cf15b_row13_col1, #T_cf15b_row13_col2, #T_cf15b_row13_col3, #T_cf15b_row13_col4, #T_cf15b_row13_col5, #T_cf15b_row13_col6, #T_cf15b_row13_col7 {
#   text-align: left;
# }
# #T_cf15b_row0_col1, #T_cf15b_row0_col2, #T_cf15b_row0_col3, #T_cf15b_row2_col5, #T_cf15b_row4_col6, #T_cf15b_row4_col7, #T_cf15b_row6_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_cf15b_row0_col8, #T_cf15b_row1_col8, #T_cf15b_row2_col8, #T_cf15b_row3_col8, #T_cf15b_row4_col8, #T_cf15b_row5_col8, #T_cf15b_row7_col8, #T_cf15b_row8_col8, #T_cf15b_row9_col8, #T_cf15b_row10_col8, #T_cf15b_row11_col8, #T_cf15b_row12_col8, #T_cf15b_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_cf15b_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_cf15b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf15b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_cf15b_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_cf15b_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_cf15b_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_cf15b_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_cf15b_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_cf15b_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_cf15b_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_cf15b_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf15b_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_cf15b_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_cf15b_row0_col1" class="data row0 col1" >0.7955</td>
#       <td id="T_cf15b_row0_col2" class="data row0 col2" >0.8404</td>
#       <td id="T_cf15b_row0_col3" class="data row0 col3" >0.7955</td>
#       <td id="T_cf15b_row0_col4" class="data row0 col4" >0.7845</td>
#       <td id="T_cf15b_row0_col5" class="data row0 col5" >0.7855</td>
#       <td id="T_cf15b_row0_col6" class="data row0 col6" >0.4309</td>
#       <td id="T_cf15b_row0_col7" class="data row0 col7" >0.4390</td>
#       <td id="T_cf15b_row0_col8" class="data row0 col8" >0.9170</td>
#     </tr>
#     <tr>
#       <th id="T_cf15b_level0_row1" class="row_heading level0 row1" >ada</th>
#       <td id="T_cf15b_row1_col0" class="data row1 col0" >Ada Boost Classifier</td>
#       <td id="T_cf15b_row1_col1" class="data row1 col1" >0.7951</td>
#       <td id="T_cf15b_row1_col2" class="data row1 col2" >0.8393</td>
#       <td id="T_cf15b_row1_col3" class="data row1 col3" >0.7951</td>
#       <td id="T_cf15b_row1_col4" class="data row1 col4" >0.7847</td>
#       <td id="T_cf15b_row1_col5" class="data row1 col5" >0.7858</td>
#       <td id="T_cf15b_row1_col6" class="data row1 col6" >0.4330</td>
#       <td id="T_cf15b_row1_col7" class="data row1 col7" >0.4403</td>
#       <td id="T_cf15b_row1_col8" class="data row1 col8" >0.4900</td>
#     </tr>
#     <tr>
#       <th id="T_cf15b_level0_row2" class="row_heading level0 row2" >lr</th>
#       <td id="T_cf15b_row2_col0" class="data row2 col0" >Logistic Regression</td>
#       <td id="T_cf15b_row2_col1" class="data row2 col1" >0.7939</td>
#       <td id="T_cf15b_row2_col2" class="data row2 col2" >0.8356</td>
#       <td id="T_cf15b_row2_col3" class="data row2 col3" >0.7939</td>
#       <td id="T_cf15b_row2_col4" class="data row2 col4" >0.7841</td>
#       <td id="T_cf15b_row2_col5" class="data row2 col5" >0.7859</td>
#       <td id="T_cf15b_row2_col6" class="data row2 col6" >0.4354</td>
#       <td id="T_cf15b_row2_col7" class="data row2 col7" >0.4407</td>
#       <td id="T_cf15b_row2_col8" class="data row2 col8" >0.9120</td>
#     </tr>
#     <tr>
#       <th id="T_cf15b_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_cf15b_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_cf15b_row3_col1" class="data row3 col1" >0.7866</td>
#       <td id="T_cf15b_row3_col2" class="data row3 col2" >0.8284</td>
#       <td id="T_cf15b_row3_col3" class="data row3 col3" >0.7866</td>
#       <td id="T_cf15b_row3_col4" class="data row3 col4" >0.7767</td>
#       <td id="T_cf15b_row3_col5" class="data row3 col5" >0.7793</td>
#       <td id="T_cf15b_row3_col6" class="data row3 col6" >0.4190</td>
#       <td id="T_cf15b_row3_col7" class="data row3 col7" >0.4231</td>
#       <td id="T_cf15b_row3_col8" class="data row3 col8" >0.6140</td>
#     </tr>
#     <tr>
#       <th id="T_cf15b_level0_row4" class="row_heading level0 row4" >lda</th>
#       <td id="T_cf15b_row4_col0" class="data row4 col0" >Linear Discriminant Analysis</td>
#       <td id="T_cf15b_row4_col1" class="data row4 col1" >0.7917</td>
#       <td id="T_cf15b_row4_col2" class="data row4 col2" >0.8259</td>
#       <td id="T_cf15b_row4_col3" class="data row4 col3" >0.7917</td>
#       <td id="T_cf15b_row4_col4" class="data row4 col4" >0.7836</td>
#       <td id="T_cf15b_row4_col5" class="data row4 col5" >0.7855</td>
#       <td id="T_cf15b_row4_col6" class="data row4 col6" >0.4374</td>
#       <td id="T_cf15b_row4_col7" class="data row4 col7" >0.4411</td>
#       <td id="T_cf15b_row4_col8" class="data row4 col8" >0.2050</td>
#     </tr>
#     <tr>
#       <th id="T_cf15b_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_cf15b_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_cf15b_row5_col1" class="data row5 col1" >0.7909</td>
#       <td id="T_cf15b_row5_col2" class="data row5 col2" >0.8258</td>
#       <td id="T_cf15b_row5_col3" class="data row5 col3" >0.7909</td>
#       <td id="T_cf15b_row5_col4" class="data row5 col4" >0.7782</td>
#       <td id="T_cf15b_row5_col5" class="data row5 col5" >0.7778</td>
#       <td id="T_cf15b_row5_col6" class="data row5 col6" >0.4075</td>
#       <td id="T_cf15b_row5_col7" class="data row5 col7" >0.4191</td>
# Processing:   0%|          | 0/61 [00:00<?, ?it/s]

# %%
best_model
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='log_loss', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_samples_leaf=1,
#                            min_samples_split=2, min_weight_fraction_leaf=0.0,
#                            n_estimators=100, n_iter_no_change=None,
#                            random_state=4181, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
df.iloc[-2:-1].shape
# Out:
# (1, 7)

# %% [markdown]
# The predict_model(best_model, df.iloc[-2:-1]) is used to predict the outcome for the second-to-last row in the DataFrame.
# It processes this single data instance and returns the original features along with the predicted class and its probabilities.

# %%
predict_model(best_model, df.iloc[-2:-1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ed25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ed25_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7ed25_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_7ed25_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_7ed25_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_7ed25_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_7ed25_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_7ed25_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_7ed25_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ed25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ed25_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_7ed25_row0_col1" class="data row0 col1" >1.0000</td>
#       <td id="T_7ed25_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_7ed25_row0_col3" class="data row0 col3" >1.0000</td>
#       <td id="T_7ed25_row0_col4" class="data row0 col4" >1.0000</td>
#       <td id="T_7ed25_row0_col5" class="data row0 col5" >1.0000</td>
#       <td id="T_7ed25_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_7ed25_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>
#             tenure PhoneService        Contract PaymentMethod  MonthlyCharges  \
# customerID
# 8361-LTMKD       4          Yes  Month-to-month  Mailed check       74.400002
#
#             TotalCharges Churn prediction_label  prediction_score
# customerID
# 8361-LTMKD    306.600006   Yes              Yes            0.6667

# %% [markdown]
# Here we can see that two new coloumns are generated prediction_label which will be for coustmour churning and predection of score

# %% [markdown]
# The best_model has saved

# %%
save_model(best_model, 'h_churn')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['tenure', 'MonthlyCharges',
#                                               'TotalCharges'],
#                                      transformer=SimpleImputer(add_indicator=False,
#                                                                copy=True,
#                                                                fill_value=None,
#                                                                keep_empty_features=False,...
#                                              criterion='friedman_mse', init=None,
#                                              learning_rate=0.1, loss='log_loss',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              random_state=4181, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False))],
#           verbose=False),
#  'h_churn.pkl')

# %% [markdown]
# The data set was load from csv file and predections was made using churn data using a pre-trained machine learining from pyCaret.Here first the data was read into a data frame and then loads the model is called best_model.after making predections it checks a specific coloumn for predection label, if it founds then it rename that coloumn to "Churn_prediction" and replaces the numeric labels (1 and 0) with  ("Churn" and "No Churn").

# %%
from pycaret.classification import load_model, predict_model

def load_data(filepath):
   
    df = pd.read_csv(filepath, index_col='customerID')
    return df

def make_predictions(df):
   
    model = load_model('best_model') 
    predictions = predict_model(model, data=df)

    print("Predictions DataFrame Columns:")
    print(predictions.columns)

    if 'prediction_label' in predictions.columns:
        predictions.rename(columns={'prediction_label': 'Churn_prediction'}, inplace=True)
        
        predictions['Churn_prediction'].replace({1: 'Churn', 0: 'No Churn'}, inplace=True)
        
        return predictions[['Churn_prediction', 'prediction_score']]
    else:
        raise KeyError("The 'prediction_label' column was not found in the predictions DataFrame")

if __name__ == "__main__":
    new_data = load_data('C:/Users/DELL/Downloads/new_churn_data.csv')
    predictions = make_predictions(new_data)
    true_values = [1, 0, 0, 1, 0]
    
    print('Predictions:')
    print(predictions)
    print('True Values:')
    print(true_values)
# Out:
# Transformation Pipeline and Model Successfully Loaded
# Predictions DataFrame Columns:
# Index(['tenure', 'PhoneService', 'Contract', 'PaymentMethod', 'MonthlyCharges',
#        'TotalCharges', 'charge_per_tenure', 'prediction_label',
#        'prediction_score'],
#       dtype='object')
# Predictions:
#            Churn_prediction  prediction_score
# customerID
# 9305-CKSKC               No            0.7682
# 1452-KNGVK               No            0.9077
# 6723-OKKJM               No            0.9669
# 7832-POPKP               No            0.8292
# 6348-TACGU               No            0.9236
# True Values:
# [1, 0, 0, 1, 0]

# %% [markdown]
# # Summary

# %% [markdown]
# Write a short summary of the process and results here.
#
#
# First, the required packages were installed, and the necessary PyCaret modules were imported to set up the AutoML environment. Various classifiers were evaluated to predict churn, and since AUC is a key metric, the Gradient Boosting Classifier (GBC) was chosen with an AUC of 0.8289, slightly higher than Logistic Regression's 0.8273. The best model was saved as best_model.pkl, along with its preprocessing pipeline. When applied to the new dataset, new_churn_data.csv, the model predicted "No Churn" for all instances, while the actual values were [1, 0, 0, 1, 0]. This indicates that the model failed to identify any churning cases, highlighting the need for further refinement to improve its predictive capabilities. Overall, this process illustrates the steps of training a model, saving it, and using it for churn predictions.
